# %%
def number_of_bullets(n , c , e):
    cash = n
    cost_of_bullet_box = c
    empty_shells = e
    number_of_boxes = n / c
    bullets = number_of_boxes * 100
    no_of_shells = bullets
    no_of_spare_shells = 0
    while (no_of_shells >= 1):# or (no_of_spare_shells == empty_shells):
        bullets += (no_of_shells//e)
        no_of_new_shells = no_of_shells//empty_shells
        no_of_spare_shells += no_of_shells%empty_shells
        
        no_of_shells = no_of_new_shells 
    
  #  if no_of_spare_shells//empty_shells == 0:
        bullets += (no_of_spare_shells//empty_shells)
        no_of_spare_shells = no_of_spare_shells%empty_shells
    print('no of shells left ' , no_of_spare_shells)
    print('no of bullets ', bullets)
        
    return bullets

# %%
number_of_bullets(100,25,4)
# Out:
# no of shells left  0.0
# no of bullets  533.0
# 533.0
